# %% [markdown]
# # Getting started #
#
# 1. You'll first of all need to install scrapy:
#
# ````
# pip install scrapy
# ````
#
# 2. Change the `start_urls` to match the pages you are scraping
#
# 3. Change the `job_title_selector` and `person_bio_link_selector` to select the required items from the page
#
# 4. Run the notebook
#
# 5. Use the output to write to file and parse the profiles for keywords

# %%
import scrapy

job_title_selector = 'div.name p strong::text'
person_bio_link_selector = 'div.name p a::attr(href)'

class RSESpider(scrapy.Spider):
    name = 'staff profile spider'
    start_urls = [
        "http://www.ncl.ac.uk/apl/staff/",
        "http://www.ncl.ac.uk/sacs/staff/",
        "http://www.ncl.ac.uk/nubs/staff/"
    ]

    def parse(self, response):
        for person in response.css('div.staff'):
            yield {'title': person.css(job_title_selector).extract_first(), 'link': person.css(person_bio_link_selector).extract_first()}

#         for next_page in response.css('div.prev-post > a'):
#             yield response.follow(next_page, self.parse)

# %%
from scrapy.crawler import CrawlerProcess
from scrapy.utils.project import get_project_settings

process = CrawlerProcess(get_project_settings())

process.crawl(RSESpider())
process.start() # the script will block here until the crawling is finished
# Out:
# 2018-03-20 16:01:43 [scrapy.utils.log] INFO: Scrapy 1.5.0 started (bot: scrapybot)
# 2018-03-20 16:01:43 [scrapy.utils.log] INFO: Versions: lxml 4.2.0.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.4.0, w3lib 1.19.0, Twisted 17.9.0, Python 3.6.4 | packaged by conda-forge | (default, Dec 23 2017, 16:31:06) - [GCC 4.8.2 20140120 (Red Hat 4.8.2-15)], pyOpenSSL 17.4.0 (OpenSSL 1.0.2n  7 Dec 2017), cryptography 2.1.4, Platform Linux-4.9.60-linuxkit-aufs-x86_64-with-debian-stretch-sid
# 2018-03-20 16:01:43 [scrapy.crawler] INFO: Overridden settings: {}
# 2018-03-20 16:01:43 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2018-03-20 16:01:43 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2018-03-20 16:01:43 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2018-03-20 16:01:43 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2018-03-20 16:01:43 [scrapy.core.engine] INFO: Spider opened
# 2018-03-20 16:01:43 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-03-20 16:01:43 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2018-03-20 16:01:43 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET http://www.ncl.ac.uk/business-school/staff> from <GET http://www.ncl.ac.uk/nubs/staff/>
# 2018-03-20 16:01:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.ncl.ac.uk/sacs/staff/> (referer: None)
# 2018-03-20 16:01:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.ncl.ac.uk/apl/staff/> (referer: None)
# 2018-03-20 16:01:43 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET http://www.ncl.ac.uk/business-school/staff/> from <GET http://www.ncl.ac.uk/business-school/staff>
# 2018-03-20 16:01:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.ncl.ac.uk/business-school/staff/> (referer: None)
# 2018-03-20 16:01:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/sacs/staff/>
# {'title': 'Marie Sklodowska-Curie Fellow', 'link': '/sacs/staff/profile/mohammedwesamamer.html'}
# 2018-03-20 16:01:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/sacs/staff/>
# {'title': 'Lecturer in Art History', 'link': '/sacs/staff/profile/fionaanderson.html'}
# 2018-03-20 16:01:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/sacs/staff/>
# {'title': 'PG Programme Secretary - MCH Programmes (part-time)', 'link': '/sacs/staff/profile/mariannearchbold.html'}
# 2018-03-20 16:01:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/sacs/staff/>
# {'title': 'Research Associate', 'link': '/sacs/staff/profile/gabiarrigoni.html'}
# 2018-03-20 16:01:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/sacs/staff/>
# {'title': 'Senior Lecturer in Media and Cultural Studies', 'link': '/sacs/staff/profile/jamesash.html'}
# 2018-03-20 16:01:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/sacs/staff/>
# {'title': 'School PA ', 'link': '/sacs/staff/profile/lilyasquith2.html'}
# 2018-03-20 16:01:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/apl/staff/>
# {'title': 'Head of School', 'link': '/apl/staff/profile/adamsharr.html'}
# 2018-03-20 16:01:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/sacs/staff/>
# {'title': 'Senior Lecturer', 'link': '/sacs/staff/profile/paulattinello.html'}
# 2018-03-20 16:01:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/sacs/staff/>
# {'title': 'Lecturer', 'link': '/sacs/staff/profile/gilesbailey.html'}
# 2018-03-20 16:01:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/sacs/staff/>
# {'title': 'Senior Lecturer', 'link': '/sacs/staff/profile/davidbaines.html'}
# 2018-03-20 16:01:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/sacs/staff/>
# {'title': 'Postgraduate Secretary (PGT)', 'link': '/sacs/staff/profile/kathybarker.html'}
# 2018-03-20 16:01:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/sacs/staff/>
# {'title': 'Lecturer in Fine Art', 'link': '/sacs/staff/profile/paulbecker.html'}
# 2018-03-20 16:01:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/apl/staff/>
# {'title': 'Professor of Architecture / Director of Architecture', 'link': '/apl/staff/profile/grahamfarmer.html'}
# 2018-03-20 16:01:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/apl/staff/>
# {'title': 'Director of Planning (DoP) ', 'link': '/apl/staff/profile/zangunn.html'}
# 2018-03-20 16:01:43 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/apl/staff/>
# {'title': 'Professor of
html'}
# 2018-03-20 16:01:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Clerical Officer (UG)', 'link': '/business-school/staff/profile/andrewwade.html'}
# 2018-03-20 16:01:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': "Int'l Undergraduate Student Officer", 'link': '/business-school/staff/profile/jameswade.html'}
# 2018-03-20 16:01:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Lecturer in Marketing', 'link': '/business-school/staff/profile/yi-chuanwang.html'}
# 2018-03-20 16:01:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': None, 'link': '/business-school/staff/profile/ruthwarwick.html'}
# 2018-03-20 16:01:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Programme Secretary', 'link': '/business-school/staff/profile/carolynwatkin.html'}
# 2018-03-20 16:01:44 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Marketing and Communications Student Intern', 'link': '/business-school/staff/profile/alexwatson.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': None, 'link': '/business-school/staff/profile/laurawatson1.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Project Officer', 'link': '/business-school/staff/profile/davidweddell.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': None, 'link': '/business-school/staff/profile/martinwetzels.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Senior Lecturer in Management', 'link': '/business-school/staff/profile/fionawhitehurst.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Chair in Management and Organization Studies', 'link': '/business-school/staff/profile/andreawhittle.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Professor of Health Economics', 'link': '/business-school/staff/profile/johnwildman.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Deputy Director of Doctoral Programmes and Degree Programme Director for N200: Senior Lecturer ', 'link': '/business-school/staff/profile/robertwillison.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Chair of Information Systems Management and Director of the Knowledge Innovation Technology Enterprise (KITE) Research Centre ', 'link': '/business-school/staff/profile/robwilson.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Research Support Officer', 'link': '/business-school/staff/profile/rosswilson.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Postgraduate Clerical Officer', 'link': '/business-school/staff/profile/aaronwinder.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': None, 'link': '/business-school/staff/profile/patrickwongsa-art.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Director of Learning & Teaching', 'link': '/business-school/staff/profile/frankworthington.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Professor of Applied Microeconomics', 'link': '/business-school/staff/profile/colinwren.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Clerical Assistant', 'link': '/business-school/staff/profile/emmawright.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Lecturer in Accounting and Finance', 'link': '/business-school/staff/profile/zhijuanwu.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Teaching Fellow in Accounting & Finance', 'link': '/business-school/staff/profile/jiayuanxin.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Senior Lecturer in International Business Strategy, Programme Director for BSc (Hon) International Business Management (London Campus)', 'link': '/business-school/staff/profile/nataliayakovleva.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Senior Lecturer in Operations Management             DPD for Dual Degree in Operations Management', 'link': '/business-school/staff/profile/yingyang2.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Reader in Marketing & Degree Program Director for MSc International Marketing', 'link': '/business-school/staff/profile/nataliayannopoulou.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Lecturer in Enterprise and Innovation', 'link': '/business-school/staff/profile/janetteyoung.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Research Associate', 'link': '/business-school/staff/profile/marinayusupova.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Teaching Fellow', 'link': '/business-school/staff/profile/sawlatzaman.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Lecturer in Accounting and Finance', 'link': '/business-school/staff/profile/yanzeng2.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Lecturer in Strategic and Operations Management', 'link': '/business-school/staff/profile/minhaozhang.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Lecturer in Banking and Finance', 'link': '/business-school/staff/profile/yangzhao.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Senior Lecturer ', 'link': '/business-school/staff/profile/wubiaozhou.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Lecturer in International Business Mngmt', 'link': '/business-school/staff/profile/jingqizhu.html'}
# 2018-03-20 16:01:45 [scrapy.core.scraper] DEBUG: Scraped from <200 http://www.ncl.ac.uk/business-school/staff/>
# {'title': 'Dean of Research & Innovation', 'link': '/business-school/staff/profile/danielzizzo.html'}
# 2018-03-20 16:01:45 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-03-20 16:01:45 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1135,
#  'downloader/request_count': 5,
#  'downloader/request_method_count/GET': 5,
#  'downloader/response_bytes': 59287,
#  'downloader/response_count': 5,
#  'downloader/response_status_count/200': 3,
#  'downloader/response_status_count/301': 2,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2018, 3, 20, 16, 1, 45, 66820),
#  'item_scraped_count': 606,
#  'log_count/DEBUG': 612,
#  'log_count/INFO': 7,
#  'memusage/max': 70914048,
#  'memusage/startup': 70914048,
#  'response_received_count': 3,
#  'scheduler/dequeued': 5,
#  'scheduler/dequeued/memory': 5,
#  'scheduler/enqueued': 5,
#  'scheduler/enqueued/memory': 5,
#  'start_time': datetime.datetime(2018, 3, 20, 16, 1, 43, 362016)}
# 2018-03-20 16:01:45 [scrapy.core.engine] INFO: Spider closed (finished)
