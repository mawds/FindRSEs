# %%
from wordcloud import WordCloud, STOPWORDS

text = open('jobs.ac.uk.txt').read()
stopwords = set(STOPWORDS)
stopwords.add("ac")
stopwords.add("uk")

wordcloud = WordCloud(max_words=100, stopwords=stopwords).generate(text)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud.words_
# Out:
# {'Athena SWAN': 0.11265432098765432,
#  'Centre': 0.2006172839506173,
#  'Closing date': 0.2345679012345679,
#  'Computer Science': 0.2654320987654321,
#  'Department': 0.21450617283950618,
#  'Engineering': 0.17901234567901234,
#  'Informal enquiries': 0.10802469135802469,
#  'Institute': 0.14660493827160495,
#  'PhD': 0.1728395061728395,
#  'School': 0.19598765432098766,
#  'Science': 0.1697530864197531,
#  'University': 0.3317901234567901,
#  'ability': 0.1095679012345679,
#  'academic': 0.24382716049382716,
#  'across': 0.11265432098765432,
#  'advanced': 0.1111111111111111,
#  'amp': 0.10802469135802469,
#  'analysis': 0.18518518518518517,
#  'applicant': 0.16820987654320987,
#  'application': 0.35648148148148145,
#  'area': 0.19907407407407407,
#  'based': 0.2762345679012346,
#  'candidate will': 0.1712962962962963,
#  'data': 0.39814814814814814,
#  'design': 0.29012345679012347,
#  'detail': 0.11728395061728394,
#  'develop': 0.16358024691358025,
#  'developing': 0.12808641975308643,
#  'development': 0.3765432098765432,
#  'environment': 0.18209876543209877,
#  'essential': 0.15432098765432098,
#  'experience': 0.6111111111111112,
#  'expertise': 0.13271604938271606,
#  'field': 0.18518518518518517,
#  'fixed term': 0.1867283950617284,
#  'full time': 0.1527777777777778,
#  'funding': 0.14506172839506173,
#  'good': 0.10802469135802469,
#  'group': 0.21450617283950618,
#  'health': 0.1111111111111111,
#  'include': 0.1867283950617284,
#  'including': 0.35648148148148145,
#  'industry': 0.14660493827160495,
#  'information': 0.25925925925925924,
#  'international': 0.14351851851851852,
#  'knowledge': 0.2515432098765432,
#  'level': 0.20679012345679013,
#  'machine learning': 0.1712962962962963,
#  'management': 0.11419753086419752,
#  'may': 0.16666666666666666,
#  'method': 0.19444444444444445,
#  'model': 0.13425925925925927,
#  'modelling': 0.13271604938271606,
#  'new': 0.25308641975308643,
#  'offer': 0.14506172839506173,
#  'part': 0.14969135802469136,
#  'partner': 0.1111111111111111,
#  'per annum': 0.16512345679012347,
#  'please contact': 0.16820987654320987,
#  'position': 0.22993827160493827,
#  'post': 0.24074074074074073,
#  'programme': 0.25617283950617287,
#  'project': 0.6219135802469136,
#  'provide': 0.16358024691358025,
#  'publication': 0.12962962962962962,
#  'qualification': 0.10648148148148148,
#  'relevant': 0.1388888888888889,
#  'required': 0.11419753086419752,
#  'requirement': 0.1419753086419753,
#  'research': 1.0,
#  'researcher': 0.15123456790123457,
#  'role': 0.18209876543209877,
#  'scientific': 0.12654320987654322,
#  'service': 0.15432098765432098,
#  'skill': 0.15432098765432098,
#  'software': 0.3410493827160494,
#  'software engineering': 0.1095679012345679,
#  'staff': 0.11882716049382716,
#  'strong': 0.15123456790123457,
#  'student': 0.2037037037037037,
#  'successful candidate': 0.1728395061728395,
#  'support': 0.2700617283950617,
#  'system': 0.35185185185185186,
#  'teaching': 0.14660493827160495,
#  'team': 0.25,
#  'technical': 0.11419753086419752,
#  'technique': 0.18364197530864199,
#  'technologies': 0.125,
#  'technology': 0.14506172839506173,
#  'tool': 0.13580246913580246,
#  'training': 0.17746913580246915,
#  'understanding': 0.1388888888888889,
#  'use': 0.17746913580246915,
#  'using': 0.17592592592592593,
#  'well': 0.24228395061728394,
#  'will': 0.6234567901234568,
#  'within': 0.2762345679012346,
#  'work': 0.3765432098765432,
#  'working': 0.13734567901234568,
#  'year': 0.1712962962962963}
